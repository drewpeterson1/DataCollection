# %% [markdown]
# Exercise: Movie Database API
#
# TMDB api site, create a developer account and access keys
#
# https://developer.themoviedb.org/reference/intro/getting-started (edited)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
API_key = "810b732dec9eb8e016394ef41919f86d"

# %%
import requests

# %%
url = "https://api.themoviedb.org/3/authentication"

# %%
headers = {"accept": "application/json", "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4MTBiNzMyZGVjOWViOGUwMTYzOTRlZjQxOTE5Zjg2ZCIsInN1YiI6IjY1Y2JmNDE1ZjkyNTMyMDE2M2MwOGUwOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ._XkSbIP_Fe5GUaQZLfNsNRtlUFEjOI1hGmqQHHwrhXI"}

# %%
response = requests.get(url, headers=headers)

# %%
response.text
# Out:
# '{"success":true,"status_code":1,"status_message":"Success."}'

# %%
print(response)
# Out:
# <Response [200]>

# %%
import requests

url = "https://api.themoviedb.org/3/trending/movie/day?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4MTBiNzMyZGVjOWViOGUwMTYzOTRlZjQxOTE5Zjg2ZCIsInN1YiI6IjY1Y2JmNDE1ZjkyNTMyMDE2M2MwOGUwOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ._XkSbIP_Fe5GUaQZLfNsNRtlUFEjOI1hGmqQHHwrhXI"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/4cNdXOV6GnLAO6yv0vflMauFfBW.jpg","id":850165,"title":"The Iron Claw","original_language":"en","original_title":"The Iron Claw","overview":"The true story of the inseparable Von Erich brothers, who made history in the intensely competitive world of professional wrestling in the early 1980s. Through tragedy and triumph, under the shadow of their domineering father and coach, the brothers seek larger-than-life immortality on the biggest stage in sports.","poster_path":"/nfs7DCYhgrEIgxKYbITHTzKsggf.jpg","media_type":"movie","genre_ids":[18],"popularity":52.914,"release_date":"2023-12-21","video":false,"vote_average":7.64,"vote_count":150},{"adult":false,"backdrop_path":"/nbq3LfgLXnL5ixZ1Q74jTJmhmTS.jpg","id":533535,"title":"Deadpool \u0026 Wolverine","original_language":"en","original_title":"Deadpool \u0026 Wolverine","overview":"Third entry in the \"Deadpool\" franchise. Plot TBA.","poster_path":"/uxBHXaoOvAwy4NpPpP7nNx2rXYQ.jpg","m
# ...

# %%
resp_json = response.json()

# %%
trending_movies = response.text

# %%
import pandas as pd

# %%
trending_df = pd.DataFrame(resp_json["results"])

# %%
trending_df.sort_values(by ="popularity", inplace=True)

# %%
trending_df.head(10)
# Out:
#     adult                     backdrop_path       id                 title  \
# 2   False  /sDrYaCGIaTcXZvns04LjTtju0Vp.jpg  1231953      Five Blind Dates
# 0   False  /4cNdXOV6GnLAO6yv0vflMauFfBW.jpg   850165         The Iron Claw
# 11  False  /cJOYsYSz3b3u0JpIWLBEfRam1eR.jpg  1014209              Suncoast
# 15  False  /kcrjQkK9XlUe0yD1cZptf4z5h3v.jpg   919207        12.12: The Day
# 1   False  /nbq3LfgLXnL5ixZ1Q74jTJmhmTS.jpg   533535  Deadpool & Wolverine
# 3   False  /pRmF6VBsRnvWCbLB9P80UvZFMyK.jpg  1014590              Upgraded
# 6   False  /3mpgltEMgPf8zFtPnAWdDVN8ZT1.jpg  1056360      American Fiction
# 10  False  /uhUO7vQQKvCTfQWubOt5MAKokbL.jpg   693134        Dune: Part Two
# 14  False  /ctMserH8g2SeOAnCw5gFjdQF8mo.jpg   346698                Barbie
# 17  False  /jYEW5xZkZk2WTrdbMGAPFuBqbDc.jpg   438631                  Dune
#
#    original_language        original_title  \
# 2                 en      Five Blind Dates
# 0                 en         The Iron Claw
# ...

# %%
def tmdb_request(website):
    headers = {"accept": "application/json", "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4MTBiNzMyZGVjOWViOGUwMTYzOTRlZjQxOTE5Zjg2ZCIsInN1YiI6IjY1Y2JmNDE1ZjkyNTMyMDE2M2MwOGUwOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ._XkSbIP_Fe5GUaQZLfNsNRtlUFEjOI1hGmqQHHwrhXI"}
    response = requests.get(website, headers=headers)
    resp_json = response.json()
    df = pd.DataFrame(resp_json["results"])
    df.sort_values(by = "popularity", inplace=True, ascending = False)
    return df

# %%
star_wars_df = tmdb_request('https://api.themoviedb.org/3/search/movie?query=star%20wars&include_adult=false&language=en-US&page=1')

# %%
star_wars_df.sort_values(by = "popularity", inplace=True, ascending = False)

# %%
star_wars_df
# Out:
#     adult                     backdrop_path                        genre_ids  \
# 0   False  /4qCqAdHcNKeAHcK8tJ8wNJZa9cx.jpg                    [12, 28, 878]
# 1   False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg                    [12, 28, 878]
# 3   False  /jOzrELAzFxtMx2I4uDGHOotdfsS.jpg                    [12, 28, 878]
# 2   False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg                    [12, 28, 878]
# 8   False  /5vDuLrjJXFS9PTF7Q1xzobmYKR9.jpg                    [12, 28, 878]
# 7   False  /sQUiouw94zhoG6LDEj9h8cPb61N.jpg                    [12, 28, 878]
# 6   False  /hDvk6O2vehwsZBdNsMSGmAVdiUn.jpg                    [878, 12, 28]
# 9   False  /abwxHfymXGAbbH3lo9PDEJEfvtW.jpg                    [12, 28, 878]
# 4   False  /6t8ES1d12OzWyCGxBeDYLHoaDrT.jpg                    [28, 12, 878]
# 15  False  /xEdnGUc8KeZ7h0eEgSN3ERhjgL0.jpg                [16, 28, 878, 12]
# 14  False  /1Lhc32P0a62BgMFgd20wXR1osR3.jpg         [16, 10751, 878, 12, 35]
# ...

# %%
dead_pool_df = tmdb_request('https://api.themoviedb.org/3/search/movie?query=dead%20pool&include_adult=false&language=en-US&page=1')

# %%
dead_pool_df
# Out:
#    adult                     backdrop_path     genre_ids      id  \
# 0  False  /vMeIYrazqkcESPW7IGAUXbnKbzI.jpg  [28, 80, 53]   10651
# 1  False                              None          [27]  479332
# 2  False                              None          [27]  533007
# 3  False  /za1jXsrgk3QBk4F5crSNeJCXoLX.jpg      [27, 28]   25727
#
#   original_language      original_title  \
# 0                en       The Dead Pool
# 1                en    Dead in the Pool
# 2                en  Dead In The Pool 2
# 3                ja             女子競泳反乱軍
#
#                                             overview  popularity  \
# 0  Dirty Harry Callahan returns for his final fil...      22.194
# 1  After being sexually attacked by her stepfathe...       1.421
# 2  Penny (Dawn Murphy), the coach's daughter from...       2.160
# 3  A psycho scientist sent in to inoculate the lu...       7.864
#
#                         poster_path release_date  \
# 0  /mqwGpW0Ptrvz1GmfCnLAOA4cQ8g.jpg   1988-07-13
# ...

# %%
deadpool_df = tmdb_request('https://api.themoviedb.org/3/search/movie?query=deadpool&include_adult=false&language=en-US&page=1')

# %%
deadpool_df
# Out:
#    adult                     backdrop_path      genre_ids      id  \
# 0  False  /en971MEXui9diirXlogOrPKmsEn.jpg   [28, 12, 35]  293660
# 1  False  /nbq3LfgLXnL5ixZ1Q74jTJmhmTS.jpg  [28, 35, 878]  533535
# 2  False  /3P52oz9HPQWxcwHOwxtyrVV1LKi.jpg   [28, 35, 12]  383498
# 3  False  /5ZSwZPKgcTJJwhxjbOHeoBTVaKh.jpg   [35, 28, 12]  567604
# 4  False   /gsljBGOjBkbuNt3gvIDXQWnudn.jpg   [28, 35, 80]  558144
#
#   original_language          original_title  \
# 0                en                Deadpool
# 1                en    Deadpool & Wolverine
# 2                en              Deadpool 2
# 3                en    Once Upon a Deadpool
# 4                en  Deadpool: No Good Deed
#
#                                             overview  popularity  \
# 0  The origin story of former Special Forces oper...     204.393
# 1  Third entry in the "Deadpool" franchise. Plot ...     166.690
# 2  Wisecracking mercenary Deadpool battles the ev...     218.203
# ...

# %%
now_df = tmdb_request('https://api.themoviedb.org/3/trending/movie/week?language=en-US')

# %%
now_df
# Out:
#     adult                     backdrop_path       id  \
# 14  False  /pWsD91G2R1Da3AKM3ymr3UoIfRb.jpg   933131
# 2   False  /yyFc8Iclt2jxPmLztbP617xXllT.jpg   787699
# 3   False  /criPrxkTggCra1jch49jsiSeXo1.jpg   609681
# 1   False  /4MCKNAc6AbWjEsM2h9Xc29owo4z.jpg   866398
# 0   False  /cnqwv5Uz3UW5f086IWbQKr3ksJr.jpg   572802
# 5   False  /meyhnvssZOPPjud4F1CjOb4snET.jpg   940551
# 17  False  /8GnWDLn2AhnmkQ7hlQ9NJUYobSS.jpg   695721
# 6   False  /ehumsuIBbgAe1hg343oszCLrAfI.jpg  1022796
# 11  False  /zLj0peaxy5y2SlC6wNIQ4V0pfqg.jpg  1139829
# 8   False  /1PkBhxXdEejw8c5BC7T3cN7jz9g.jpg  1072790
# 10  False  /fm6KqXpk3M2HVveHwCrBSSBaO0V.jpg   872585
# 9   False  /bQS43HSLZzMjZkcHJz4fGc7fNdz.jpg   792307
# 15  False  /rx6FXL5Pu2FQC3HrowNQrdqojnM.jpg   634492
# 12  False  /ctMserH8g2SeOAnCw5gFjdQF8mo.jpg   346698
# 4   False  /8te0oIAuUOxi03RbM1SfL3xUYHB.jpg   848538
# 16  False  /uhUO7vQQKvCTfQWubOt5MAKokbL.jpg   693134
# 7   False  /3mpgltEMgPf8zFtPnAWdDVN8ZT1.jpg  1056360
# ...

# %%
requests.__version__
# Out:
# '2.31.0'

# %%
import bs4

bs4.__version__
# Out:
# '4.12.2'

# %%
import pandas
pandas.__version__
# Out:
# '2.1.4'

# %%
for each feature create a new feature
    What would be a problem
Talk about feature
